# %% [markdown]
# ## task 4.3.

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# Turn your project folder path into a string as outlined in the Exercise text.
path = r'C:\Users\dog\Desktop\Instacart Basket Analysis'

# %%
# Import the “orders.csv” data set into your notebook using the os library and the vars_list shortcut,
# omitting the “eval_set” column in your final dataframe.
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
# Import the “orders.csv” data set into your notebook using the os library and the vars_list shortcut,
# omitting the “eval_set” column in your final dataframe.
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
## Print the first 5 rows of your dataframe.
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#import the “products.csv” file into Jupyter as df_prods (as opposed to df, which is what your “orders.csv” file is named in Jupyter).
#You can use the path variable you created in step 4 to import “products.csv” with the os library.

df_prod = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Print the first 20 rows and last 35 rows of the df_prods dataframe. I have used append, because I have found it in stack overflow :)) 

df_prod.head(20).append(df.tail(35))
# Out:
# C:\Users\dog\AppData\Local\Temp\ipykernel_6536\2138919157.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_prod.head(20).append(df.tail(35))
#          product_id                                       product_name  \
# 0               1.0                         Chocolate Sandwich Cookies
# 1               2.0                                   All-Seasons Salt
# 2               3.0               Robust Golden Unsweetened Oolong Tea
# 3               4.0  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5.0                          Green Chile Anytime Sauce
# 5               6.0                                       Dry Nose Oil
# 6               7.0                     Pure Coconut Water With Orange
# 7               8.0                  Cut Russet Potatoes Steam N' Mash
# 8               9.0                  Light Strawberry Blueberry Yogurt
# ...

# %%
# Print the names of the columns in the df_prods dataframe.
df_prod.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
# Print the number of rows and columns in the df_prods dataframe. (we could use shape or describe, however her ewe see much more information)
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  object
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# # Answer the following questions using the relevant commands. Use markdown mode for your Jupyter cells to provide written answers within your Jupyter notebook after executing the commands:
#
# ### What’s the maximum value of the “aisle_id” column?   134.000000 . see next row with describe function
# ### What’s the data type of the “department_id” column? int64 . see previous row with info function

# %%
# What’s the maximum value of the “aisle_id” column? 
df_prod.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000
